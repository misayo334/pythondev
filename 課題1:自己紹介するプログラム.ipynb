# %%
#命令１
print("名前を入力してください：")
name = input("名前を入力してください：")
print(name)

#命令2
print("現在の年齢を入力してください：")
age = input("現在の年齢を入力してください：")
age = int(age)
print(age)

#命令３
print("私の名前は",name,"です。")
print("来年で",age + 1,"歳になります。")
# Out:
# 名前を入力してください：
# きより
# 現在の年齢を入力してください：
# 5
# 私の名前は きより です。
# 来年で 6 歳になります。
