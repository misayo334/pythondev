# %%
import prognum

try:
    a = int(input("何番目の数値を求めますか？："))
    if a < 1:
        print("1以上の整数が入力されませんでした。")
    else:
        print(f"何番目の数値を求めますか？：{a}")
        print(prognum.fibo(a))

except:
    print("1以上の整数が入力されませんでした。")
# Out:
# 何番目の数値を求めますか？：20
# 6765
